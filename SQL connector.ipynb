# %%
pip install mysql-connector-python --q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Mh20dk#1234567890"
)

# Create a cursor
cursor = conn.cursor()

# Create  database
cursor.execute("CREATE DATABASE IF NOT EXISTS UniversityAnalysis")
print("Database created successfully")
# Out:
# Database created successfully

# %%
conn = mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Mh20dk#1234567890",
    database="UniversityAnalysis"
)

# %%
cursor = conn.cursor()

# %%
from sqlalchemy import create_engine

# connection string
connection_string = 'mysql+pymysql://root:Mh20dk#1234567890@127.0.0.1:3306/UniversityAnalysis'

# %%
students = pd.read_csv("students.csv")
students
# Out:
#     StudentID FirstName  LastName  Gender         DOB  \
# 0      ZPOGSG       Pam      Luna  Female  2000-05-19
# 1      VYS67G      Todd  Robinson    Male  2005-10-09
# 2      DMQ4BP   Tiffany    Nelson    Male  2000-07-13
# 3      3PB4C7    Rachel     Smith    Male  2002-06-05
# 4      5Q4V66      Eric    Nelson  Female  2003-04-15
# ..        ...       ...       ...     ...         ...
# 995    NEGKJI     Jesse   Goodwin  Female  2005-02-19
# 996    3XKT7K     Diana    Miller    Male  1998-06-24
# 997    FBR4DD    Curtis       Fox    Male  1998-08-25
# 998    APDAIY  Samantha    Fields    Male  2003-04-19
# 999    7A2N5C  Michelle     Clark  Female  2005-04-04
#
#                             Email            PhoneNumber                City  \
# 0    jacksongabrielle@example.org      (310)712-5059x903  South Kennethhaven
# 1          danielle14@example.org  +1-569-848-6178x58059    South Judithport
# 2            daniel07@example.net           567.761.4610           Aprilport
# ...

# %%
# Create students table
cursor.execute("""
CREATE TABLE IF NOT EXISTS students (
    StudentID VARCHAR(100),
    FirstName VARCHAR(100),
    LastName VARCHAR(100),
    Gender VARCHAR(100),
    DOB DATE,
    Email VARCHAR(100),
    PhoneNumber VARCHAR(100),
    City VARCHAR(100),
    State VARCHAR(100),
    Country VARCHAR(100),
    Address VARCHAR(255),
    PinCode VARCHAR(10)
)
""")

# %%
pip install pymysql --q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
engine = create_engine(connection_string)

# %%
students.to_sql('students', con=engine, if_exists='append', index=False)
# Out:
# 1000

# %%
departments = pd.read_csv("departments.csv")
departments
# Out:
#   DepartmentID    DepartmentName  DepartmentHead
# 0         D001  Computer Science  Gabriel Rangel
# 1         D002       Mathematics  Donald Jimenez
# 2         D003           Physics   Steve Wiggins
# 3         D004         Chemistry  Kelly Hamilton
# 4         D005           Biology  Robert Salazar

# %%
# Create departments table
cursor.execute("""
CREATE TABLE IF NOT EXISTS departments (
    DepartmentID VARCHAR(100),
    DepartmentName VARCHAR(100), 
    DepartmentHead VARCHAR(100)
    )
""")
print("Departments table created successfully")
# Out:
# Departments table created successfully

# %%
departments.to_sql('departments', con=engine, if_exists='append', index=False)
# Out:
# 5

# %%
courses = pd.read_csv("courses.csv")
courses
# Out:
#    CourseID                        CourseName DepartmentID  CreditHours
# 0      VHWU  Introduction to Computer Science         D001            4
# 1      890Q    Data Structures and Algorithms         D001            3
# 2      MWBK       Database Management Systems         D001            3
# 3      ULJK                 Operating Systems         D001            4
# 4      KC44                 Computer Networks         D001            3
# 5      TRGV              Software Engineering         D001            1
# 6      3K8X           Artificial Intelligence         D001            4
# 7      L1Y2                  Machine Learning         D001            1
# 8      37PD        Cybersecurity Fundamentals         D001            2
# 9      PNLZ                   Web Development         D001            4
# 10     RCPK                        Calculus I         D002            3
# 11     999T                       Calculus II         D002            1
# ...

# %%
# Create courses table
cursor.execute("""
CREATE TABLE IF NOT EXISTS courses (
    CourseID VARCHAR(100),
    CourseName VARCHAR(100), 
    DepartmentID VARCHAR(100),
    CreditHours VARCHAR(100)
    )
""")
print("Courses table created successfully")
# Out:
# Courses table created successfully

# %%
courses.to_sql('courses', con=engine, if_exists='append', index=False)
# Out:
# 50

# %%
enrollments = pd.read_csv("enrollments.csv")
enrollments
# Out:
#      StudentID CourseID EnrollmentDate
# 0       ZPOGSG     ULJK     2022-10-22
# 1       ZPOGSG     3K8X     2023-05-19
# 2       ZPOGSG     999T     2022-11-22
# 3       ZPOGSG     R3F6     2022-11-19
# 4       ZPOGSG     M58E     2023-01-24
# ...        ...      ...            ...
# 3999    APDAIY     8OYP     2021-11-21
# 4000    7A2N5C     3K8X     2021-09-11
# 4001    7A2N5C     ADW2     2022-01-09
# 4002    7A2N5C     3ER3     2023-02-28
# 4003    7A2N5C     Z3WJ     2023-05-18
#
# [4004 rows x 3 columns]

# %%
# Create enrollments table
cursor.execute("""
CREATE TABLE IF NOT EXISTS enrollments (
    StudentID VARCHAR(100),
    CourseID VARCHAR(100), 
    EnrollmentDate DATE
    )
""")
print("Enrollments table created successfully")
# Out:
# Enrollments table created successfully

# %%
enrollments.to_sql('enrollments', con=engine, if_exists='append', index=False)
# Out:
# 4004

# %%
faculty = pd.read_csv("faculty.csv")
faculty
# Out:
#    FacultyID        FacultyName DepartmentID             Position  \
# 0     FKDLL7         Allen Reed         D003  Assistant Professor
# 1     XCEAUJ         Jane Dixon         D005            Professor
# 2     UG0CBI       Debbie Klein         D001  Associate Professor
# 3     FDBGLZ       Tanya Rogers         D004  Associate Professor
# 4     IUJRQS       David Pineda         D005  Assistant Professor
# ..       ...                ...          ...                  ...
# 95    PLVSS9      Jeremy Vargas         D004  Associate Professor
# 96    1MCQVB    Gabriel Daniels         D001  Assistant Professor
# 97    5A27E0      Mark Martinez         D004  Associate Professor
# 98    XT7JPQ  Jacqueline Willis         D002  Assistant Professor
# 99    9OD6GU     Andre Faulkner         D002            Professor
#
#                         Email                 Phone  Rating
# 0     smithrhonda@example.org  001-874-650-4472x333    1.75
# ...

# %%
# Create faculty table
cursor.execute("""
CREATE TABLE IF NOT EXISTS faculty (
    FacultyID VARCHAR(100),
    FacultyName VARCHAR(100), 
    DepartmentID VARCHAR(100),
    Position VARCHAR(100),
    Email VARCHAR(100),
    Phone VARCHAR(100),
    Rating FLOAT
    )
""")
print("Faculty table created successfully")
# Out:
# Faculty table created successfully

# %%
faculty.to_sql('faculty', con=engine, if_exists='append', index=False)
# Out:
# 100

# %%
grades = pd.read_csv("grades.csv")
grades
# Out:
#      StudentID CourseID Semester Grade
# 0       ZPOGSG     ULJK   Winter     D
# 1       ZPOGSG     3K8X   Summer     B
# 2       ZPOGSG     999T     Fall     E
# 3       ZPOGSG     R3F6     Fall     B
# 4       ZPOGSG     M58E   Summer     A
# ...        ...      ...      ...   ...
# 3999    APDAIY     8OYP   Summer     C
# 4000    7A2N5C     3K8X     Fall     E
# 4001    7A2N5C     ADW2   Summer     C
# 4002    7A2N5C     3ER3   Summer     B
# 4003    7A2N5C     Z3WJ   Summer     C
#
# [4004 rows x 4 columns]

# %%
# Create grades table
cursor.execute("""
CREATE TABLE IF NOT EXISTS grades (
    StudentID VARCHAR(100),
    CourseID VARCHAR(100), 
    Semester VARCHAR(100),
    Grade VARCHAR(100)
    )
""")
print("Grades table created successfully")
# Out:
# Grades table created successfully

# %%
grades.to_sql('grades', con=engine, if_exists='append', index=False)
# Out:
# 4004

# %%
department_budgets = pd.read_csv("department_budgets.csv")
department_budgets
# Out:
#    DepartmentID  Year      Budget
# 0          D001  2019  3218698.13
# 1          D001  2020  2977515.35
# 2          D001  2021  4312572.46
# 3          D001  2022  1775182.90
# 4          D001  2023  3748404.24
# 5          D002  2019  4267031.70
# 6          D002  2020   301546.74
# 7          D002  2021  2816853.86
# 8          D002  2022  2625214.93
# 9          D002  2023  3237040.40
# 10         D003  2019   115642.22
# 11         D003  2020  4052435.66
# 12         D003  2021  2412563.92
# 13         D003  2022  2275885.23
# 14         D003  2023  4338013.44
# 15         D004  2019  1869959.88
# 16         D004  2020  3820640.68
# 17         D004  2021  3780427.12
# 18         D004  2022  3907385.87
# 19         D004  2023   512110.65
# 20         D005  2019  2187554.68
# 21         D005  2020  3167392.23
# 22         D005  2021  4633233.73
# 23         D005  2022  1601124.98
# 24         D005  2023  2377295.77

# %%
# Create department_budgets table
cursor.execute("""
CREATE TABLE IF NOT EXISTS department_budgets (
    DepartmentID VARCHAR(100), 
    Year YEAR,
    Budget VARCHAR(100)
    )
""")
print("department_budgets table created successfully")
# Out:
# department_budgets table created successfully

# %%
department_budgets.to_sql('department_budgets', con=engine, if_exists='append', index=False)
# Out:
# 25

# %%
attendance_df = pd.read_csv("attendance.csv")
attendance_df
# Out:
#        StudentID CourseID        Date   Status
# 0         ZPOGSG     ULJK  2023-07-21   Absent
# 1         ZPOGSG     ULJK  2023-01-27   Absent
# 2         ZPOGSG     ULJK  2023-10-21  Present
# 3         ZPOGSG     ULJK  2023-10-26   Absent
# 4         ZPOGSG     ULJK  2024-05-03  Present
# ...          ...      ...         ...      ...
# 119755    7A2N5C     Z3WJ  2023-10-16  Present
# 119756    7A2N5C     Z3WJ  2023-07-25  Present
# 119757    7A2N5C     Z3WJ  2024-03-22   Absent
# 119758    7A2N5C     Z3WJ  2023-12-24   Absent
# 119759    7A2N5C     Z3WJ  2024-04-27   Absent
#
# [119760 rows x 4 columns]

# %%
# Create attendance table
cursor.execute("""
CREATE TABLE IF NOT EXISTS attendance (
    StudentID VARCHAR(100), 
    CourseID VARCHAR(100),
    Date DATE,
    Status VARCHAR(100)
    
    )
""")
print("attendance table created successfully")
# Out:
# attendance table created successfully

# %%
attendance_df.to_sql('attendance', con=engine, if_exists='append', index=False)
# Out:
# 119760

# %%
scholarships_df = pd.read_csv("scholarships.csv")
scholarships_df
# Out:
#    ScholarshipID                   ScholarshipName   Amount  \
# 0         45RZZW   Academic Excellence Scholarship  2367.70
# 1         J939FH  Athletic Achievement Scholarship  4795.93
# 2         PG91PB               Research Fellowship  2996.91
# 3         F6BA6A            Need-Based Scholarship  3474.63
# 4         S1UBM8                  Leadership Award  1550.57
# ..           ...                               ...      ...
# 95        9GAVKI                  Leadership Award  1923.58
# 96        BZJAU3                  Leadership Award  1083.53
# 97        I9P32J               Research Fellowship  3911.90
# 98        Y5OL8Q            Need-Based Scholarship  2892.65
# 99        K4JK82            Need-Based Scholarship  2288.53
#
#                                  Provider StudentID   AwardDate  \
# 0                   Gates Cambridge Trust    1RHKJB  2024-02-16
# 1                   Gates Cambridge Trust    R3QOLZ  2021-10-13
# ...

# %%
# Create scholarships table
cursor.execute("""
CREATE TABLE IF NOT EXISTS scholarships (
    ScholarshipID VARCHAR(100), 
    ScholarshipName VARCHAR(250),
    Amount FLOAT,
    Provider VARCHAR(250),
    StudentID VARCHAR(100),
    AwardDate DATE,
    Reason VARCHAR(100)
    
    )
""")
print("scholarships table created successfully")
# Out:
# scholarships table created successfully

# %%
scholarships_df.to_sql('scholarships', con=engine, if_exists='append', index=False)
# Out:
# 100

# %%
placements_df = pd.read_csv("placements.csv")
placements_df
# Out:
#    PlacementID StudentID               CompanyName  \
# 0       AU1F3U    P7D978  Bright Ideas Corporation
# 1       VH3BX9    YCW3DJ               SparkleSoft
# 2       AR0R8Q    8KZZ43      Techwise Innovations
# 3       7QUIEL    GWVMSM   Futurewave Technologies
# 4       9COU2X    7CQYLT    Global Innovations Ltd
# ..         ...       ...                       ...
# 95      AQSHXV    8G4PJM             Nova Dynamics
# 96      TXMPTJ    2GZD1U      Quantum Technologies
# 97      FSVLUJ    RZ9V2E           Swift Solutions
# 98      G1PCCB    YD6XLN             Nova Dynamics
# 99      HTMOJB    MRYQF2   Futurewave Technologies
#
#                        JobTitle     Salary PlacementDate        Department
# 0                  Statistician  128966.34    2021-12-13       Mathematics
# 1                     Ecologist  130893.74    2024-02-13           Biology
# 2        Database Administrator   80330.01    2023-05-27  Computer Science
# ...

# %%
# Create placements table
cursor.execute("""
CREATE TABLE IF NOT EXISTS placements (
    PlacementID VARCHAR(100), 
    StudentID VARCHAR(100),
    CompanyName VARCHAR(250),
    JobTitle VARCHAR(100),
    Salary FLOAT,
    PlacementDate DATE,
    Department VARCHAR(100)
    
    )
""")
print("placements table created successfully")
# Out:
# placements table created successfully

# %%
placements_df.to_sql('placements', con=engine, if_exists='append', index=False)
# Out:
# 100
